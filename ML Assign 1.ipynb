# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("uber.csv")
df.head()
# Out:
#    Unnamed: 0                            key  fare_amount  \
# 0    24238194    2015-05-07 19:52:06.0000003          7.5
# 1    27835199    2009-07-17 20:04:56.0000002          7.7
# 2    44984355   2009-08-24 21:45:00.00000061         12.9
# 3    25894730    2009-06-26 08:22:21.0000001          5.3
# 4    17610152  2014-08-28 17:47:00.000000188         16.0
#
#            pickup_datetime  pickup_longitude  pickup_latitude  \
# 0  2015-05-07 19:52:06 UTC        -73.999817        40.738354
# 1  2009-07-17 20:04:56 UTC        -73.994355        40.728225
# 2  2009-08-24 21:45:00 UTC        -74.005043        40.740770
# 3  2009-06-26 08:22:21 UTC        -73.976124        40.790844
# 4  2014-08-28 17:47:00 UTC        -73.925023        40.744085
#
#    dropoff_longitude  dropoff_latitude  passenger_count
# 0         -73.999512         40.723217                1
# 1         -73.994710         40.750325                1
# 2         -73.962565         40.772647                1
# 3         -73.965316         40.803349                3
# 4         -73.973082         40.761247                5

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200000 entries, 0 to 199999
# Data columns (total 9 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   Unnamed: 0         200000 non-null  int64
#  1   key                200000 non-null  object
#  2   fare_amount        200000 non-null  float64
#  3   pickup_datetime    200000 non-null  object
#  4   pickup_longitude   200000 non-null  float64
#  5   pickup_latitude    200000 non-null  float64
#  6   dropoff_longitude  199999 non-null  float64
#  7   dropoff_latitude   199999 non-null  float64
#  8   passenger_count    200000 non-null  int64
# dtypes: float64(5), int64(2), object(2)
# memory usage: 13.7+ MB

# %%
df.describe()
# Out:
#          Unnamed: 0    fare_amount  pickup_longitude  pickup_latitude  \
# count  2.000000e+05  200000.000000     200000.000000    200000.000000
# mean   2.771250e+07      11.359955        -72.527638        39.935885
# std    1.601382e+07       9.901776         11.437787         7.720539
# min    1.000000e+00     -52.000000      -1340.648410       -74.015515
# 25%    1.382535e+07       6.000000        -73.992065        40.734796
# 50%    2.774550e+07       8.500000        -73.981823        40.752592
# 75%    4.155530e+07      12.500000        -73.967154        40.767158
# max    5.542357e+07     499.000000         57.418457      1644.421482
#
#        dropoff_longitude  dropoff_latitude  passenger_count
# count      199999.000000     199999.000000    200000.000000
# mean          -72.525292         39.923890         1.684535
# std            13.117408          6.794829         1.385997
# min         -3356.666300       -881.985513         0.000000
# 25%           -73.991407         40.733823         1.000000
# 50%           -73.980093         40.753042         1.000000
# 75%           -73.963658         40.768001         2.000000
# max          1153.572603        872.697628       208.000000

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'key', 'fare_amount', 'pickup_datetime',
#        'pickup_longitude', 'pickup_latitude', 'dropoff_longitude',
#        'dropoff_latitude', 'passenger_count'],
#       dtype='object')

# %%
df = df.drop(['Unnamed: 0', 'key'], axis= 1)

# %%
df.head()
# Out:
#    fare_amount          pickup_datetime  pickup_longitude  pickup_latitude  \
# 0          7.5  2015-05-07 19:52:06 UTC        -73.999817        40.738354
# 1          7.7  2009-07-17 20:04:56 UTC        -73.994355        40.728225
# 2         12.9  2009-08-24 21:45:00 UTC        -74.005043        40.740770
# 3          5.3  2009-06-26 08:22:21 UTC        -73.976124        40.790844
# 4         16.0  2014-08-28 17:47:00 UTC        -73.925023        40.744085
#
#    dropoff_longitude  dropoff_latitude  passenger_count
# 0         -73.999512         40.723217                1
# 1         -73.994710         40.750325                1
# 2         -73.962565         40.772647                1
# 3         -73.965316         40.803349                3
# 4         -73.973082         40.761247                5

# %%
df.shape #To get the total (Rows,Columns)
# Out:
# (200000, 7)

# %%
df.dtypes
# Out:
# fare_amount          float64
# pickup_datetime       object
# pickup_longitude     float64
# pickup_latitude      float64
# dropoff_longitude    float64
# dropoff_latitude     float64
# passenger_count        int64
# dtype: object

# %%
df.isnull().sum()
# Out:
# fare_amount          0
# pickup_datetime      0
# pickup_longitude     0
# pickup_latitude      0
# dropoff_longitude    1
# dropoff_latitude     1
# passenger_count      0
# dtype: int64

# %%
df['dropoff_latitude'].fillna(value=df['dropoff_latitude'].mean(),inplace = True)
df['dropoff_longitude'].fillna(value=df['dropoff_longitude'].median(),inplace = True)

# %%
df.isnull().sum()
# Out:
# fare_amount          0
# pickup_datetime      0
# pickup_longitude     0
# pickup_latitude      0
# dropoff_longitude    0
# dropoff_latitude     0
# passenger_count      0
# dtype: int64

# %%
#Column pickup_datetime is in wrong format (Object). Convert it to DateTime Format

df.pickup_datetime = pd.to_datetime(df.pickup_datetime, errors='coerce')

# %%
df.dtypes
# Out:
# fare_amount                      float64
# pickup_datetime      datetime64[ns, UTC]
# pickup_longitude                 float64
# pickup_latitude                  float64
# dropoff_longitude                float64
# dropoff_latitude                 float64
# passenger_count                    int64
# dtype: object

# %%
#To segregate each time of date and time

df= df.assign(hour = df.pickup_datetime.dt.hour,
day= df.pickup_datetime.dt.day,
month = df.pickup_datetime.dt.month,
year = df.pickup_datetime.dt.year,
dayofweek = df.pickup_datetime.dt.dayofweek)

# %%
df.head()
# Out:
#    fare_amount           pickup_datetime  pickup_longitude  pickup_latitude  \
# 0          7.5 2015-05-07 19:52:06+00:00        -73.999817        40.738354
# 1          7.7 2009-07-17 20:04:56+00:00        -73.994355        40.728225
# 2         12.9 2009-08-24 21:45:00+00:00        -74.005043        40.740770
# 3          5.3 2009-06-26 08:22:21+00:00        -73.976124        40.790844
# 4         16.0 2014-08-28 17:47:00+00:00        -73.925023        40.744085
#
#    dropoff_longitude  dropoff_latitude  passenger_count  hour  day  month  \
# 0         -73.999512         40.723217                1    19    7      5
# 1         -73.994710         40.750325                1    20   17      7
# 2         -73.962565         40.772647                1    21   24      8
# 3         -73.965316         40.803349                3     8   26      6
# 4         -73.973082         40.761247                5    17   28      8
#
#    year  dayofweek
# 0  2015          3
# 1  2009          4
# 2  2009          0
# 3  2009          4
# 4  2014          3

# %%
df.plot(kind = "box",subplots = True,layout = (7,2),figsize=(15,20)) #
# Out:
# fare_amount             AxesSubplot(0.125,0.787927;0.352273x0.0920732)
# pickup_longitude     AxesSubplot(0.547727,0.787927;0.352273x0.0920732)
# pickup_latitude         AxesSubplot(0.125,0.677439;0.352273x0.0920732)
# dropoff_longitude    AxesSubplot(0.547727,0.677439;0.352273x0.0920732)
# dropoff_latitude        AxesSubplot(0.125,0.566951;0.352273x0.0920732)
# passenger_count      AxesSubplot(0.547727,0.566951;0.352273x0.0920732)
# hour                    AxesSubplot(0.125,0.456463;0.352273x0.0920732)
# day                  AxesSubplot(0.547727,0.456463;0.352273x0.0920732)
# month                   AxesSubplot(0.125,0.345976;0.352273x0.0920732)
# year                 AxesSubplot(0.547727,0.345976;0.352273x0.0920732)
# dayofweek               AxesSubplot(0.125,0.235488;0.352273x0.0920732)
# dtype: object

# %%
def remove_outlier(df1 , col):       # Using the InterQuartile Range to fill the values

  Q1 = df1[col].quantile(0.25)
  Q3 = df1[col].quantile(0.75)
  IQR = Q3 - Q1
  lower_whisker = Q1-1.5*IQR
  upper_whisker = Q3+1.5*IQR
  df[col] = np.clip(df1[col] , lower_whisker , upper_whisker)
  return df1

def treat_outliers_all(df1 , col_list):
  for c in col_list:
    df1 = remove_outlier(df , c)
  return df1

# %%
df = treat_outliers_all(df , df.iloc[: , 0::])

# %%
df.plot(kind = "box",subplots = True,layout = (7,2),figsize=(15,20))
# Out:
# fare_amount             AxesSubplot(0.125,0.787927;0.352273x0.0920732)
# pickup_longitude     AxesSubplot(0.547727,0.787927;0.352273x0.0920732)
# pickup_latitude         AxesSubplot(0.125,0.677439;0.352273x0.0920732)
# dropoff_longitude    AxesSubplot(0.547727,0.677439;0.352273x0.0920732)
# dropoff_latitude        AxesSubplot(0.125,0.566951;0.352273x0.0920732)
# passenger_count      AxesSubplot(0.547727,0.566951;0.352273x0.0920732)
# hour                    AxesSubplot(0.125,0.456463;0.352273x0.0920732)
# day                  AxesSubplot(0.547727,0.456463;0.352273x0.0920732)
# month                   AxesSubplot(0.125,0.345976;0.352273x0.0920732)
# year                 AxesSubplot(0.547727,0.345976;0.352273x0.0920732)
# dayofweek               AxesSubplot(0.125,0.235488;0.352273x0.0920732)
# dtype: object

# %%
from math import *

# %% [markdown]
# Haversine Formula Calculatin the distance between the pickup and drop co-ordinates using the Haversine formual for accuracy.
#
# hav(θ) = sin**2(θ/2).

# %%
# function to calculate the travel distance from the longitudes and latitudes
def distance_transform(longitude1, latitude1, longitude2, latitude2):
    travel_dist = []
    
    for pos in range(len(longitude1)):
        long1,lati1,long2,lati2 = map(radians,[longitude1[pos],latitude1[pos],longitude2[pos],latitude2[pos]])
        dist_long = long2 - long1
        dist_lati = lati2 - lati1
        a = sin(dist_lati/2)**2 + cos(lati1) * cos(lati2) * sin(dist_long/2)**2
        c = 2 * asin(sqrt(a))*6371
        travel_dist.append(c)
       
    return travel_dist

# %%
df['dist_travel_km'] = distance_transform(df['pickup_longitude'].to_numpy(),
                                                df['pickup_latitude'].to_numpy(),
                                                df['dropoff_longitude'].to_numpy(),
                                                df['dropoff_latitude'].to_numpy()
                                              )

# %%
sns.heatmap(df.isnull()) #Free for null values

# %%
corr = df.corr()

corr.style.background_gradient(cmap='BuGn')
# Out:
# <style type="text/css">
# #T_a9c15_row0_col0, #T_a9c15_row1_col1, #T_a9c15_row2_col2, #T_a9c15_row3_col3, #T_a9c15_row4_col4, #T_a9c15_row5_col5, #T_a9c15_row6_col6, #T_a9c15_row7_col7, #T_a9c15_row8_col8, #T_a9c15_row9_col9, #T_a9c15_row10_col10, #T_a9c15_row11_col11 {
#   background-color: #00441b;
#   color: #f1f1f1;
# }
# #T_a9c15_row0_col1 {
#   background-color: #dbf2f2;
#   color: #000000;
# }
# #T_a9c15_row0_col2, #T_a9c15_row0_col4, #T_a9c15_row1_col5, #T_a9c15_row2_col5, #T_a9c15_row2_col11, #T_a9c15_row3_col5, #T_a9c15_row4_col0, #T_a9c15_row6_col3, #T_a9c15_row6_col10, #T_a9c15_row8_col7, #T_a9c15_row8_col9, #T_a9c15_row9_col5, #T_a9c15_row9_col8, #T_a9c15_row10_col1, #T_a9c15_row10_col6 {
#   background-color: #f7fcfd;
#   color: #000000;
# }
# #T_a9c15_row0_col3 {
#   background-color: #ccece6;
#   color: #000000;
# }
# #T_a9c15_row0_col5 {
#   background-color: #f3fafc;
#   color: #000000;
# }
# #T_a9c15_row0_col6, #T_a9c15_row1_col10, #T_a9c15_row9_col3, #T_a9c15_row10_col2, #T_a9c15_row10_col5 {
#   background-color: #eff9fb;
#   color: #000000;
# }
# #T_a9c15_row0_col7, #T_a9c15_row5_col7, #T_a9c15_row6_col7, #T_a9c15_row7_col1, #T_a9c15_row8_col1, #T_a9c15_row8_col5, #T_a9c15_row10_col7, #T_a9c15_row11_col5 {
#   background-color: #f4fbfc;
#   color: #000000;
# }
# #T_a9c15_row0_col8, #T_a9c15_row6_col4 {
#   background-color: #e4f5f8;
#   color: #000000;
# }
# #T_a9c15_row0_col9 {
#   background-color: #d1eee9;
#   color: #000000;
# }
# #T_a9c15_row0_col10, #T_a9c15_row1_col6, #T_a9c15_row2_col3, #T_a9c15_row2_col9, #T_a9c15_row6_col0, #T_a9c15_row7_col9 {
#   background-color: #eaf7fa;
#   color: #000000;
# }
# #T_a9c15_row0_col11 {
#   background-color: #147e3a;
#   color: #f1f1f1;
# }
# #T_a9c15_row1_col0 {
#   background-color: #cdece6;
#   color: #000000;
# }
# #T_a9c15_row1_col2 {
#   background-color: #aadfd3;
#   color: #000000;
# }
# #T_a9c15_row1_col3 {
#   background-color: #7acbb3;
#   color: #000000;
# }
# #T_a9c15_row1_col4 {
#   background-color: #dbf1f1;
#   color: #000000;
# }
# #T_a9c15_row1_col7, #T_a9c15_row2_col0, #T_a9c15_row2_col7, #T_a9c15_row3_col7, #T_a9c15_row4_col7 {
#   background-color: #f5fbfd;
#   color: #000000;
# }
# #T_a9c15_row1_col8, #T_a9c15_row2_col6, #T_a9c15_row2_col8, #T_a9c15_row3_col8, #T_a9c15_row4_col8, #T_a9c15_row5_col4, #T_a9c15_row6_col9, #T_a9c15_row7_col4, #T_a9c15_row9_col4, #T_a9c15_row10_col9, #T_a9c15_row11_col10 {
#   background-color: #e8f6fa;
#   color: #000000;
# }
# #T_a9c15_row1_col9, #T_a9c15_row1_col11, #T_a9c15_row3_col9, #T_a9c15_row5_col8, #T_a9c15_row7_col0, #T_a9c15_row8_col4, #T_a9c15_row11_col8 {
#   background-color: #e7f6f9;
#   color: #000000;
# }
# #T_a9c15_row2_col1 {
#   background-color: #c2e8e0;
#   color: #000000;
# }
# #T_a9c15_row2_col4 {
#   background-color: #52b78b;
#   color: #f1f1f1;
# }
# #T_a9c15_row2_col10, #T_a9c15_row7_col3, #T_a9c15_row8_col3, #T_a9c15_row10_col3 {
#   background-color: #f1fafc;
#   color: #000000;
# }
# #T_a9c15_row3_col0 {
#   background-color: #b5e3d9;
#   color: #000000;
# }
# #T_a9c15_row3_col1 {
#   background-color: #7fcdb6;
#   color: #000000;
# }
# #T_a9c15_row3_col2 {
#   background-color: #e2f4f7;
#   color: #000000;
# }
# #T_a9c15_row3_col4 {
#   background-color: #acdfd4;
#   color: #000000;
# }
# #T_a9c15_row3_col6, #T_a9c15_row5_col3, #T_a9c15_row6_col1, #T_a9c15_row6_col5, #T_a9c15_row6_col11, #T_a9c15_row9_col1, #T_a9c15_row11_col2 {
#   background-color: #f2fafc;
#   color: #000000;
# }
# #T_a9c15_row3_col10, #T_a9c15_row5_col11, #T_a9c15_row8_col6, #T_a9c15_row8_col11 {
#   background-color: #ecf8fb;
#   color: #000000;
# }
# #T_a9c15_row3_col11 {
#   background-color: #d4efec;
#   color: #000000;
# }
# #T_a9c15_row4_col1, #T_a9c15_row4_col6, #T_a9c15_row4_col9, #T_a9c15_row5_col6, #T_a9c15_row5_col9, #T_a9c15_row6_col8, #T_a9c15_row7_col2, #T_a9c15_row8_col2, #T_a9c15_row10_col8, #T_a9c15_row10_col11 {
#   background-color: #e9f7fa;
#   color: #000000;
# }
# #T_a9c15_row4_col2 {
#   background-color: #53b88c;
#   color: #f1f1f1;
# }
# #T_a9c15_row4_col3 {
#   background-color: #c0e7df;
#   color: #000000;
# }
# #T_a9c15_row4_col5, #T_a9c15_row5_col1, #T_a9c15_row9_col7 {
#   background-color: #f6fcfd;
#   color: #000000;
# }
# #T_a9c15_row4_col10, #T_a9c15_row11_col6 {
#   background-color: #f0f9fb;
#   color: #000000;
# }
# #T_a9c15_row4_col11, #T_a9c15_row7_col5, #T_a9c15_row11_col7 {
#   background-color: #f5fbfc;
#   color: #000000;
# }
# #T_a9c15_row5_col0, #T_a9c15_row5_col10, #T_a9c15_row6_col2, #T_a9c15_row10_col0, #T_a9c15_row11_col9 {
#   background-color: #e5f5f9;
#   color: #000000;
# }
# #T_a9c15_row5_col2, #T_a9c15_row7_col6, #T_a9c15_row7_col8, #T_a9c15_row7_col10, #T_a9c15_row9_col2, #T_a9c15_row9_col10, #T_a9c15_row9_col11, #T_a9c15_row10_col4 {
#   background-color: #ebf7fa;
#   color: #000000;
# }
# #T_a9c15_row7_col11, #T_a9c15_row8_col10, #T_a9c15_row11_col1 {
#   background-color: #edf8fb;
#   color: #000000;
# }
# #T_a9c15_row8_col0 {
#   background-color: #e3f4f7;
#   color: #000000;
# }
# #T_a9c15_row9_col0 {
#   background-color: #cfede8;
#   color: #000000;
# }
# #T_a9c15_row9_col6 {
#   background-color: #ecf8fa;
#   color: #000000;
# }
# #T_a9c15_row11_col0 {
#   background-color: #127c39;
#   color: #f1f1f1;
# }
# #T_a9c15_row11_col3 {
#   background-color: #d8f0ef;
#   color: #000000;
# }
# #T_a9c15_row11_col4 {
#   background-color: #eef8fb;
#   color: #000000;
# }
# </style>
# <table id="T_a9c15_" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >fare_amount</th>
#       <th class="col_heading level0 col1" >pickup_longitude</th>
#       <th class="col_heading level0 col2" >pickup_latitude</th>
#       <th class="col_heading level0 col3" >dropoff_longitude</th>
#       <th class="col_heading level0 col4" >dropoff_latitude</th>
#       <th class="col_heading level0 col5" >passenger_count</th>
#       <th class="col_heading level0 col6" >hour</th>
#       <th class="col_heading level0 col7" >day</th>
#       <th class="col_heading level0 col8" >month</th>
#       <th class="col_heading level0 col9" >year</th>
#       <th class="col_heading level0 col10" >dayofweek</th>
#       <th class="col_heading level0 col11" >dist_travel_km</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a9c15_level0_row0" class="row_heading level0 row0" >fare_amount</th>
#       <td id="T_a9c15_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_a9c15_row0_col1" class="data row0 col1" >0.154069</td>
#       <td id="T_a9c15_row0_col2" class="data row0 col2" >-0.110842</td>
#       <td id="T_a9c15_row0_col3" class="data row0 col3" >0.218675</td>
#       <td id="T_a9c15_row0_col4" class="data row0 col4" >-0.125898</td>
#       <td id="T_a9c15_row0_col5" class="data row0 col5" >0.015778</td>
#       <td id="T_a9c15_row0_col6" class="data row0 col6" >-0.023623</td>
#       <td id="T_a9c15_row0_col7" class="data row0 col7" >0.004534</td>
#       <td id="T_a9c15_row0_col8" class="data row0 col8" >0.030817</td>
#       <td id="T_a9c15_row0_col9" class="data row0 col9" >0.141277</td>
#       <td id="T_a9c15_row0_col10" class="data row0 col10" >0.013652</td>
#       <td id="T_a9c15_row0_col11" class="data row0 col11" >0.786385</td>
#     </tr>
#     <tr>
#       <th id="T_a9c15_level0_row1" class="row_heading level0 row1" >pickup_longitude</th>
#       <td id="T_a9c15_row1_col0" class="data row1 col0" >0.154069</td>
#       <td id="T_a9c15_row1_col1" class="data row1 col1" >1.000000</td>
#       <td id="T_a9c15_row1_col2" class="data row1 col2" >0.259497</td>
#       <td id="T_a9c15_row1_col3" class="data row1 col3" >0.425619</td>
#       <td id="T_a9c15_row1_col4" class="data row1 col4" >0.073290</td>
#       <td id="T_a9c15_row1_col5" class="data row1 col5" >-0.013213</td>
#       <td id="T_a9c15_row1_col6" class="data row1 col6" >0.011579</td>
#       <td id="T_a9c15_row1_col7" class="data row1 col7" >-0.003204</td>
#       <td id="T_a9c15_row1_col8" class="data row1 col8" >0.001169</td>
#       <td id="T_a9c15_row1_col9" class="data row1 col9" >0.010198</td>
#       <td id="T_a9c15_row1_col10" class="data row1 col10" >-0.024652</td>
#       <td id="T_a9c15_row1_col11" class="data row1 col11" >0.048446</td>
#     </tr>
#     <tr>
#       <th id="T_a9c15_level0_row2" class="row_heading level0 row2" >pickup_latitude</th>
#       <

# %%
x = df[['pickup_longitude','pickup_latitude','dropoff_longitude','dropoff_latitude','passenger_count']]

y = df['fare_amount']

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(x,y,test_size = 0.35)

# %%
from sklearn.linear_model import LinearRegression
regression = LinearRegression()

# %%
regression.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
regression.intercept_ #To find the linear intercept
# Out:
# 7368.972838646455

# %%
regression.coef_ #To find the linear coeeficient
# Out:
# array([ 23.70927818, -13.80298492,  51.99813192, -29.34935889,
#          0.10996545])

# %%
prediction = regression.predict(X_test) #To predict the target values

# %%
print(prediction)
# Out:
# [ 8.11050592  8.76797007  9.88445283 ...  9.38480331  8.30864559
#  13.27911803]

# %%
y_test
# Out:
# 178718     7.30
# 151887     6.50
# 56927     22.25
# 193159     7.30
# 39562      6.50
#           ...
# 18952      3.70
# 53081      6.10
# 18499      6.90
# 54090      7.30
# 145377    14.10
# Name: fare_amount, Length: 70000, dtype: float64

# %%
from sklearn import metrics
print('Mean Absolute Error:', metrics.mean_absolute_error(y_test, prediction))
print('Mean Squared Error:', metrics.mean_squared_error(y_test, prediction))
print('Root Mean Squared Error:', np.sqrt(metrics.mean_squared_error(y_test, prediction)))
# Out:
# Mean Absolute Error: 4.123494370479266
# Mean Squared Error: 26.945858716175028
# Root Mean Squared Error: 5.190940060930681

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
rf = RandomForestRegressor(n_estimators=100)

# %%
rf.fit(X_train,y_train)
# Out:
# RandomForestRegressor()

# %%
y_pred = rf.predict(X_test)
y_pred
# Out:
# array([ 5.219 ,  6.208 , 22.25  , ...,  6.053 ,  9.256 , 16.3915])

# %%
from sklearn.metrics import r2_score

# %%
R2_Random = r2_score(y_test,y_pred)
R2_Random
# Out:
# 0.7621715560324858

# %%
from sklearn import metrics
print('Mean Absolute Error:', metrics.mean_absolute_error(y_test, y_pred))
print('Mean Squared Error:', metrics.mean_squared_error(y_test, y_pred))
print('Root Mean Squared Error:', np.sqrt(metrics.mean_squared_error(y_test, y_pred)))
# Out:
# Mean Absolute Error: 1.7275853506308
# Mean Squared Error: 7.0482897436731085
# Root Mean Squared Error: 2.65486153003751
